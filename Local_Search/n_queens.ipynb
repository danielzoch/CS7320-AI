# %% [markdown]
# # Solving the n-Queens Problem using Local Search
#
# Student Name: Daniel Zoch
#
# I have used the following AI tools: [list tools]
#
# I understand that my submission needs to be my own work: DZ
#
# ## Instructions
#
# Total Points: Undergrads 100 / Graduate students 110
#
# Complete this notebook. Use the provided notebook cells and insert additional code and markdown cells as needed. Submit the completely rendered notebook as a PDF file.

# %% [markdown]
# ## The n-Queens Problem
#
# * __Goal:__ Find an arrangement of $n$ queens on a $n \times n$ chess board so that no queen is on the same row, column or diagonal as any other queen.
#
# * __State space:__ An arrangement of the queens on the board. We restrict the state space to arrangements where there is only a single queen per column. We represent a state as an integer vector $\mathbf{q} = \{q_1, q_2, \dots, q_n\}$, each number representing the row positions of the queens from left to right. We will call a state a "board."
#
# * __Objective function:__ The number of pairwise conflicts (i.e., two queens in the same row/column/diagonal).
# The optimization problem is to find the optimal arrangement $\mathbf{q}^*$ of $n$ queens on the board can be written as:
#
#   > minimize: $\mathrm{conflicts}(\mathbf{q})$
#   >
#   > subject to: $\mathbf{q} \ \text{contains only one queen per column}$
#
#   Note: the constraint (subject to) is enforced by the definition of the state space.
#
# * __Local improvement move:__ Move one queen to a different row in its column.
#
# * __Termination:__ For this problem there is always an arrangement $\mathbf{q}^*$ with $\mathrm{conflicts}(\mathbf{q}^*) = 0$, however, the local improvement moves might end up in a local minimum.

# %% [markdown]
# ## Helper functions

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

np.random.seed(1234)


def random_board(n):
    """Creates a random board of size n x n. Note that only a single queen is placed in each column!"""
    
    return(np.random.randint(0,n, size = n))

def comb2(n): return n*(n-1)//2 # this is n choose 2 equivalent to math.comb(n, 2); // is int division

def conflicts(board):
    """Calculate the number of conflicts, i.e., the objective function."""

    n = len(board)
    
    horizontal_cnt = [0] * n
    diagonal1_cnt = [0] * 2 * n
    diagonal2_cnt = [0] * 2 * n
    
    for i in range(n):
        horizontal_cnt[board[i]] += 1
        diagonal1_cnt[i + board[i]] += 1
        diagonal2_cnt[i - board[i] + n] += 1
    
    return sum(map(comb2, horizontal_cnt + diagonal1_cnt + diagonal2_cnt))

# decrease the fontsize to fit larger boards
def show_board(board, cols = ['white', 'gray'], fontsize = 48):  
    """display the board"""
    
    n = len(board)
    
    # create chess board display
    display = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            if (((i+j) % 2) != 0): 
                display[i,j] = 1
    
    cmap = colors.ListedColormap(cols)
    fig, ax = plt.subplots()
    ax.imshow(display, cmap = cmap, 
              norm = colors.BoundaryNorm(range(len(cols)+1), cmap.N))
    ax.set_xticks([])
    ax.set_yticks([])
    
    # place queens. Note: Unicode u265B is a black queen
    for j in range(n):
        plt.text(j, board[j], u"\u265B", fontsize = fontsize, 
                 horizontalalignment = 'center',
                 verticalalignment = 'center')
    
    print(f"Board with {conflicts(board)} conflicts.")
    plt.show()

# %% [markdown]
# ## Create a board

# %%
board = random_board(4)

show_board(board)
print(f"Queens (left to right) are at rows: {board}")
print(f"Number of conflicts: {conflicts(board)}")
# Out:
# Board with 4 conflicts.
# Queens (left to right) are at rows: [3 3 2 1]
# Number of conflicts: 4

# %% [markdown]
# A board $4 \times 4$ with no conflicts:

# %%
board = [1,3,0,2]
show_board(board)
# Out:
# Board with 0 conflicts.

# %% [markdown]
# # Tasks
#
# ## General [10 Points]
#
# 1. Make sure that you use the latest version of this notebook. Sync your forked repository and pull the latest revision.
# 2. Your implementation can use libraries like math, numpy, scipy, but not libraries that implement intelligent agents or complete search algorithms. Try to keep the code simple! In this course, we want to learn about the algorithms and we often do not need to use object-oriented design.
# 3. You notebook needs to be formatted professionally.
#     - Add additional markdown blocks for your description, comments in the code, add tables and use mathplotlib to produce charts where appropriate
#     - Do not show debugging output or include an excessive amount of output.
#     - Check that your PDF file is readable. For example, long lines are cut off in the PDF file. You don't have control over page breaks, so do not worry about these.
# 4. Document your code. Add a short discussion of how your implementation works and your design choices.

# %% [markdown]
# ## Task 1: Steepest-ascend Hill Climbing Search [30 Points]
#
# Calculate the objective function for all local moves (see definition of local moves above) and always choose the best among all local moves. If there are no local moves that improve the objective, then you have reached a local optimum.

# %%
def steepestAscendHillClimbing(n, maxIterations=1000):
    bestBoard = random_board(n)
    bestConflicts = conflicts(bestBoard)
    
    for _ in range(maxIterations):
        neighbors = [bestBoard.copy() for _ in range(n)]
        for i in range(n):
            for j in range(n):
                neighbors[i][j] = j
        
        for neighbor in neighbors:
            neighborConflicts = conflicts(neighbor)
            if neighborConflicts < bestConflicts:
                bestBoard = neighbor
                bestConflicts = neighborConflicts
        
        if bestConflicts == 0:
            break
    
    return bestBoard, bestConflicts

n = 8  # board size
bestBoard, bestConflicts = steepestAscendHillClimbing(n)
print(f"Best board found with {bestConflicts} conflicts:")
show_board(bestBoard)
# Out:
# Best board found with 8 conflicts:
# Board with 8 conflicts.

# %% [markdown]
# ## Task 2: Stochastic Hill Climbing 1 [10 Points]
#
# Chooses randomly from among all uphill moves till you have reached a local optimum.

# %%
def stochasticHillClimbing1(n, maxIterations=1000):
    currentBoard = random_board(n)
    currentConflicts = conflicts(currentBoard)
    
    for _ in range(maxIterations):
        neighbors = [currentBoard.copy() for _ in range(n)]
        for i in range(n):
            for j in range(n):
                neighbors[i][j] = j
        
        uphillNeighbors = []
        for neighbor in neighbors:
            neighborConflicts = conflicts(neighbor)
            if neighborConflicts < currentConflicts:
                uphillNeighbors.append(neighbor)
        
        if not uphillNeighbors:
            break
        
        chosenNeighbor = np.random.choice(uphillNeighbors)
        currentBoard = chosenNeighbor
        currentConflicts = conflicts(currentBoard)
        
        if currentConflicts == 0:
            break
    
    return currentBoard, currentConflicts

n = 8  # board size
bestBoard, bestConflicts = stochasticHillClimbing1(n)
print(f"Best board found with {bestConflicts} conflicts:")
show_board(bestBoard)
# Out:
# Best board found with 8 conflicts:
# Board with 8 conflicts.

# %% [markdown]
# ## Task 3: Stochastic Hill Climbing 2 [20 Points]
#
# A popular version of stochastic hill climbing generates only a single random local neighbor at a time and accept it if it has a better objective function value than the current state. This is very efficient if each state has many possible successor states. This method is called "First-choice hill climbing" in the textbook.
#
# __Notes:__
#
# * Detecting local optima is tricky! You can, for example, stop if you were not able to improve the objective function during the last $x$ tries.

# %%
def stochasticHillClimbing2(n, maxIterations=1000, maxAttempts=10):
    bestBoard = random_board(n)
    bestConflicts = conflicts(bestBoard)
    
    for _ in range(maxAttempts):
        currentBoard = random_board(n)
        currentConflicts = conflicts(currentBoard)
        
        for _ in range(maxIterations):
            neighbors = [currentBoard.copy() for _ in range(n)]
            for i in range(n):
                for j in range(n):
                    neighbors[i][j] = j
            
            uphillNeighbors = []
            for neighbor in neighbors:
                neighborConflicts = conflicts(neighbor)
                if neighborConflicts < currentConflicts:
                    uphillNeighbors.append(neighbor)
            
            if not uphillNeighbors:
                break
            
            chosenNeighbor = np.random.choice(uphillNeighbors)
            currentBoard = chosenNeighbor
            currentConflicts = conflicts(currentBoard)
            
            if currentConflicts == 0:
                return currentBoard, currentConflicts
    
    return bestBoard, bestConflicts

n = 8  # board size
bestBoard, bestConflicts = stochasticHillClimbing2(n)
print(f"Best board found with {bestConflicts} conflicts:")
show_board(bestBoard)
# Out:
# Best board found with 7 conflicts:
# Board with 7 conflicts.

# %% [markdown]
# ## Task 4: Hill Climbing Search with Random Restarts [10 Points]
#
# Hill climbing will often end up in local optima. Restart the each of the three hill climbing algorithm up to 100 times with a random board to find a better (hopefully optimal) solution. Note that restart just means to run the algorithm several times starting with a new random board.

# %%
def hillClimbingWithRestarts(n, maxIterations=1000, maxRestarts=100):
    bestBoard = random_board(n)
    bestConflicts = conflicts(bestBoard)
    
    for _ in range(maxRestarts):
        currentBoard = random_board(n)
        currentConflicts = conflicts(currentBoard)
        
        for _ in range(maxIterations):
            neighbors = [currentBoard.copy() for _ in range(n)]
            for i in range(n):
                for j in range(n):
                    neighbors[i][j] = j
            
            uphillNeighbors = []
            for neighbor in neighbors:
                neighborConflicts = conflicts(neighbor)
                if neighborConflicts < currentConflicts:
                    uphillNeighbors.append(neighbor)
            
            if not uphillNeighbors:
                break
            
            chosenNeighbor = np.random.choice(uphillNeighbors)
            currentBoard = chosenNeighbor
            currentConflicts = conflicts(currentBoard)
            
            if currentConflicts == 0:
                return currentBoard, currentConflicts
        
        if currentConflicts < bestConflicts:
            bestBoard = currentBoard
            bestConflicts = currentConflicts
    
    return bestBoard, bestConflicts

n = 8  # board size
bestBoard, bestConflicts = hillClimbingWithRestarts(n)
print(f"Best board found with {bestConflicts} conflicts:")
show_board(bestBoard)
# Out:
# Best board found with 4 conflicts:
# Board with 4 conflicts.

# %% [markdown]
# ## Task 5: Simulated Annealing [10 Points]
#
# Simulated annealing is a form of stochastic hill climbing that avoid local optima by also allowing downhill moves with a probability proportional to a temperature. The temperature is decreased in every iteration following an annealing schedule. You have to experiment with the annealing schedule (Google to find guidance on this).
#
#
# 1. Implement simulated annealing for the n-Queens problem.
# 2. Compare the performance with the previous algorithms.
# 2. Discuss your choice of annealing schedule.

# %%
def simulatedAnnealing(n, maxIterations=1000, maxTemp=100, minTemp=1, alpha=0.9):
    currentBoard = random_board(n)
    currentConflicts = conflicts(currentBoard)
    bestBoard = currentBoard
    bestConflicts = currentConflicts

    currentTemp = maxTemp
    while currentTemp > minTemp:
        for _ in range(maxIterations):
            newBoard = random_board(n)
            newConflicts = conflicts(newBoard)

            if newConflicts < currentConflicts or np.random.uniform(0, 1) < np.exp((currentConflicts - newConflicts) / currentTemp):
                currentBoard = newBoard
                currentConflicts = newConflicts

                if newConflicts < bestConflicts:
                    bestBoard = newBoard
                    bestConflicts = newConflicts

        currentTemp *= alpha

    return bestBoard, bestConflicts

n = 8  # board size
bestBoardSA, bestConflictsSA = simulatedAnnealing(n)
print(f"Best board found with {bestConflictsSA} conflicts:")
show_board(bestBoardSA)
# Out:
# Best board found with 1 conflicts:
# Board with 1 conflicts.

# %% [markdown]
# In AI, Simulated Annealing is used to find a solution through optimization. It's based off of the idea that materials can be slowly cooled in order to find its lowest energy state from metallurgical applications.
#
# In this context, 'maxTemp' and 'minTemp' are used in controlling the extent of exploration of the search space and allowing the algorithm to also escape local optima. As 'maxTemp' decreases, its probability of accepting solutions that are less optimal increases and the algorithm focuses on more promising solutions towards an optimal solution. The annealing schedule above is implemented by gradually reducing the temperature over iterations gradually, ensuring that the search process transitions effeciently and that we find the global optimum.

# %% [markdown]
# ## Task 6: Compare Performance [10 Points]
#
# Use runtime and objective function value to compare the algorithms.
#
# * Use boards of different sizes to explore how the different algorithms perform. Make sure that you run the algorithms for each board size several times (at least 10 times) with different starting boards and report averages.
#
# * How do the algorithms scale with problem size? Use tables and charts.
#
# * What is the largest board each algorithm can solve in a reasonable amount time?
#
# See [Profiling Python Code](../HOWTOs/profiling_code.ipynb) for help about how to measure runtime in Python.

# %%
import time

def runAlgorithm(algorithm, n, maxIterations=1000, maxRestarts=100, repetitions=10):
    runtimes = []
    conflictsList = []
    for _ in range(repetitions):
        startTime = time.time()
        bestBoard, bestConflicts = algorithm(n)
        endTime = time.time()
        runtime = endTime - startTime
        runtimes.append(runtime)
        conflictsList.append(bestConflicts)
    avgRuntime = sum(runtimes) / repetitions
    avgConflicts = sum(conflictsList) / repetitions
    return avgRuntime, avgConflicts

nValues = [4, 8, 12, 16, 20]
results = []

for n in nValues:
    steepestAscendRuntime, steepestAscendConflicts = runAlgorithm(steepestAscendHillClimbing, n)
    stochasticHillClimbing1Runtime, stochasticHillClimbing1Conflicts = runAlgorithm(stochasticHillClimbing1, n)
    stochasticHillClimbing2Runtime, stochasticHillClimbing2Conflicts = runAlgorithm(stochasticHillClimbing2, n)
    hillClimbingWithRestartsRuntime, hillClimbingWithRestartsConflicts = runAlgorithm(hillClimbingWithRestarts, n)
    simulatedAnnealingRuntime, simulatedAnnealingConflicts = runAlgorithm(simulatedAnnealing, n)
    
    results.append((n, steepestAscendRuntime, steepestAscendConflicts,
                    stochasticHillClimbing1Runtime, stochasticHillClimbing1Conflicts,
                    stochasticHillClimbing2Runtime, stochasticHillClimbing2Conflicts,
                    hillClimbingWithRestartsRuntime, hillClimbingWithRestartsConflicts,
                    simulatedAnnealingRuntime, simulatedAnnealingConflicts))

print("Results:")
print("  n   |  Steepest Ascend  |  Stochastic HC1  |  Stochastic HC2  |  HC with Restarts | Simulated Annealing")
print("-" * 70)
for row in results:
    n, steepestAscendRuntime, steepestAscendConflicts, stochasticHillClimbing1Runtime, \
    stochasticHillClimbing1Conflicts, stochasticHillClimbing2Runtime, stochasticHillClimbing2Conflicts, \
    hillClimbingWithRestartsRuntime, hillClimbingWithRestartsConflicts, \
    simulatedAnnealingRuntime, simulatedAnnealingConflicts = row

    print(f" {n:^4} | {steepestAscendConflicts:^16.2f} | {stochasticHillClimbing1Conflicts:^16.2f} | "
          f"{stochasticHillClimbing2Conflicts:^16.2f} | {hillClimbingWithRestartsConflicts:^16.2f} | "
          f"{simulatedAnnealingConflicts:^16.2f}")

import matplotlib.pyplot as plt

nValues = [row[0] for row in results]
steepestAscendConflicts = [row[2] for row in results]
stochasticHillClimbing1Conflicts = [row[4] for row in results]
stochasticHillClimbing2Conflicts = [row[6] for row in results]
hillClimbingWithRestartsConflicts = [row[8] for row in results]
simulatedAnnealingConflicts = [row[10] for row in results]

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.plot(nValues, steepestAscendConflicts, marker='o', label='Steepest Ascend')
plt.plot(nValues, stochasticHillClimbing1Conflicts, marker='o', label='Stochastic HC1')
plt.plot(nValues, stochasticHillClimbing2Conflicts, marker='o', label='Stochastic HC2')
plt.plot(nValues, hillClimbingWithRestartsConflicts, marker='o', label='HC with Restarts')
plt.plot(nValues, simulatedAnnealingConflicts, marker='o', label='Simualted Annealing')
plt.xlabel('Board Size (n)')
plt.ylabel('Average Conflicts')
plt.title('Average Conflicts vs. Board Size')
plt.legend()

plt.subplot(122)
steepestAscendRuntime = [row[1] for row in results]
stochasticHillClimbing1Runtime = [row[3] for row in results]
stochasticHillClimbing2Runtime = [row[5] for row in results]
hillClimbingWithRestartsRuntime = [row[7] for row in results]
simulatedAnnealingRuntime = [row[9] for row in results]

plt.plot(nValues, steepestAscendRuntime, marker='o', label='Steepest Ascend')
plt.plot(nValues, stochasticHillClimbing1Runtime, marker='o', label='Stochastic HC1')
plt.plot(nValues, stochasticHillClimbing2Runtime, marker='o', label='Stochastic HC2')
plt.plot(nValues, hillClimbingWithRestartsRuntime, marker='o', label='HC with Restarts')
plt.plot(nValues, simulatedAnnealingRuntime, marker='o', label='Simualted Annealing')
plt.xlabel('Board Size (n)')
plt.ylabel('Average Runtime (s)')
plt.title('Average Runtime vs. Board Size')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Results:
#   n   |  Steepest Ascend  |  Stochastic HC1  |  Stochastic HC2  |  HC with Restarts | Simulated Annealing
# ----------------------------------------------------------------------
#   4   |       3.50       |       2.60       |       3.40       |       0.40       |       0.00
#   8   |       9.70       |       9.60       |       6.50       |       2.90       |       0.70
#   12  |      14.00       |      13.10       |      12.60       |       5.90       |       3.00
#   16  |      16.20       |      16.60       |      16.00       |       9.00       |       5.20
#   20  |      26.10       |      20.40       |      23.10       |      12.40       |       7.90

# %% [markdown]
# ## Graduate student advanced task: Exploring other Local Moves [10 Points]
#
# __Undergraduate students:__ This is a bonus task you can attempt if you like [+5 Bonus Points].
#
# Implement a few different local moves. Implement:
#
# * moving a queen only one square at a time
# * switching two columns
# * more moves which move more than one queen at a time.
#
# Compare the performance of these moves for the 8-Queens problem using your stochastic hill climbing 2 implementation from above. Also consider mixing the use of several types of local moves (e.g., move one queen and moving two queens).
#
# Describe what you find out about how well these moves and combinations of these moves work.

# %% [markdown]
# The following modified Stochastic Hill Climbing 2 function has the three suggested moves implemented. This allows for the algorithm to explore local optima more effectively because it can explore solutions more diversely. It's efficiency will depend on its ability to navigate the problem space, and the structure of the original board. These combinations and be assessed by comparing runtime performance against the number of conflicts as before, as well as the time to find a global optimum.

# %%
import random
import numpy as np

def stochasticHillClimbing2(n, maxIterations=1000, maxAttempts=10):
    bestBoard = random_board(n)
    bestConflicts = conflicts(bestBoard)
    
    for _ in range(maxAttempts):
        currentBoard = random_board(n)
        currentConflicts = conflicts(currentBoard)
        
        for _ in range(maxIterations):
            neighbors = [currentBoard.copy() for _ in range(n)]
            for i in range(n):
                for j in range(n):
                    neighbors[i][j] = j
            
            uphillNeighbors = []
            for neighbor in neighbors:
                neighborConflicts = conflicts(neighbor)
                if neighborConflicts < currentConflicts:
                    uphillNeighbors.append(neighbor)
                    
            # Additional local moves
            for i in range(n):
                for j in range(n):
                    # Move a queen one square at a time
                    for k in range(n):
                        if currentBoard[i] != k:
                            neighbor = currentBoard.copy()
                            neighbor[i] = k
                            neighborConflicts = conflicts(neighbor)
                            if neighborConflicts < currentConflicts:
                                uphillNeighbors.append(neighbor)
                    
                    # Switch two columns
                    for k in range(n):
                        if currentBoard[i] != currentBoard[k]:
                            neighbor = currentBoard.copy()
                            neighbor[i], neighbor[k] = neighbor[k], neighbor[i]
                            neighborConflicts = conflicts(neighbor)
                            if neighborConflicts < currentConflicts:
                                uphillNeighbors.append(neighbor)
                    
                    # Move more than one queen at a time
                    for k in range(n):
                        if currentBoard[i] != k and currentBoard[k] != currentBoard[i]:
                            neighbor = currentBoard.copy()
                            neighbor[i] = k
                            neighbor[k] = currentBoard[i]
                            neighborConflicts = conflicts(neighbor)
                            if neighborConflicts < currentConflicts:
                                uphillNeighbors.append(neighbor)
            
            if not uphillNeighbors:
                break
            
            chosenNeighbor = random.choice(uphillNeighbors)
            currentBoard = chosenNeighbor
            currentConflicts = conflicts(currentBoard)
            
            if currentConflicts == 0:
                return currentBoard, currentConflicts
    
    return bestBoard, bestConflicts

n = 8
bestBoard, bestConflicts = stochasticHillClimbing2(n)
print(f"Best board found with {bestConflicts} conflicts:")
show_board(bestBoard)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\school\repos\CS7320-AI\Local_Search\n_queens.ipynb Cell 25 line 6
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=64'>65</a>     return bestBoard, bestConflicts
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=66'>67</a> n = 8
# ---> <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=67'>68</a> bestBoard, bestConflicts = stochasticHillClimbing2(n)
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=68'>69</a> print(f"Best board found with {bestConflicts} conflicts:")
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=69'>70</a> show_board(bestBoard)
#
# e:\school\repos\CS7320-AI\Local_Search\n_queens.ipynb Cell 25 line 5
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=54'>55</a> if not uphillNeighbors:
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=55'>56</a>     break
# ---> <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=57'>58</a> chosenNeighbor = np.random.choice(uphillNeighbors)
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=58'>59</a> currentBoard = chosenNeighbor
#      <a href='vscode-notebook-cell:/e%3A/school/repos/CS7320-AI/Local_Search/n_queens.ipynb#Y154sZmlsZQ%3D%3D?line=59'>60</a> currentConflicts = conflicts(currentBoard)
#
# File mtrand.pyx:911, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be 1-dimensional

# %% [markdown]
# ## More things to do
#
# Implement a Genetic Algorithm for the n-Queens problem.
